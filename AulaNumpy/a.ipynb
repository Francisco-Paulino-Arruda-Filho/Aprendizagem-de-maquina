# %%
import numpy as np

# %%
np.ones((3,1))
# Out:
# array([[1.],
#        [1.],
#        [1.]])

# %%
A = np.array([[1],
              [1],
              [1]])

B = np.array([[5,10],
              [6,11],
              [7,12]])

np.hstack((A,B))
# Out:
# array([[ 1,  5, 10],
#        [ 1,  6, 11],
#        [ 1,  7, 12]])
